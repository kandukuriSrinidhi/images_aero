# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# Read the dataset from a CSV file
data = pd.read_csv('/content/rainfall in india 1901-2015 (2) (1).csv')
# Print the dataset to inspect its contents
print(data)
# Extract the target variable 'ANNUAL' and handle missing values by filling them with 0
y = data['ANNUAL'].fillna(0)
#print(y)
# Extract the features by dropping the 'ANNUAL' and 'SUBDIVISION' columns, and handle missing values by filling them with 0
x = data.drop(['ANNUAL','SUBDIVISION'], axis=1).fillna(0)
#print(x)
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
# Import the pandas library
import pandas as pd
# Read your dataset from a CSV file and store it in a DataFrame
data = pd.read_csv('/content/rainfall in india 1901-2015 (2) (1).csv')
# Get the number of rows and columns in the DataFrame
num_rows, num_columns = data.shape
# Print the number of rows and columns
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 4116
# Number of columns: 19

# %%
# Import the pandas library
import pandas as pd
# Read your dataset from a CSV file and store it in a DataFrame
data = pd.read_csv('/content/rainfall in india 1901-2015 (2) (1).csv')
# Group the data by the 'YEAR' column and calculate the annual mean for each year
# You can use other aggregation functions like .sum(), .median(), .max(), .min(), etc.
annual_data = data.groupby('YEAR').mean()
# Print the resulting DataFrame with annual means
print(annual_data)
#Calculate the annual mean for each group using MEAN function mean(average) which results in the annual mean
# Out:
#             JAN        FEB        MAR        APR        MAY         JUN  \
# YEAR
# 1901  35.220000  40.508571  21.097143  46.388571  70.434286  194.608571
# 1902   8.520000   8.305714  20.951429  45.771429  72.040000  168.820000
# 1903  16.851429  14.342857  26.577143  16.974286  80.237143  171.988571
# 1904  11.697143   9.391429  28.880000  41.402857  92.454286  237.485714
# 1905  23.200000  20.477143  40.940000  34.754286  76.437143  164.805714
# ...         ...        ...        ...        ...        ...         ...
# 2011  14.341667  22.769444  27.744444  49.325000  71.561111  241.102778
# 2012  27.485714   9.663889  11.891667  58.241667  50.244444  183.308333
# 2013  12.108333  36.563889  17.477778  31.600000  82.802778  297.419444
# 2014  16.180556  25.647222  29.441667  22.052778  91.013889  142.261111
# 2015  19.052778  16.825000  51.730556  76.225000  75.525000  239.355556
#
#              JUL         AUG         SEP         OCT        NOV        DEC  \
# YEAR
# ...

# %%
# Import the necessary libraries for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# Create a histogram for the 'ANNUAL' column using Seaborn
# 'data['ANNUAL']' selects the data for the 'ANNUAL' rainfall column
# The 'kde=True' parameter overlays a Kernel Density Estimation (KDE) plot on top of the histogram for a smooth density estimation
sns.histplot(data['ANNUAL'], kde=True)
# Label the x-axis
plt.xlabel('ANNUAL Rainfall')
# Label the y-axis
plt.ylabel('Frequency')
# Set the title of the plot
plt.title('Histogram of ANNUAL Rainfall')
# Display the histogram and KDE plot
plt.show()

# %%
# Display concise information about the DataFrame using the 'info' method
# Setting 'verbose=True' makes the information more detailed
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
# Assuming you have a DataFrame 'data' with a column 'year' and other relevant data
# Define a list of years you want to analyze
years_to_describe = [1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910]
# Filter the data for the specified years
filtered_data = data[data['YEAR'].isin(years_to_describe)]
# Use the describe function on the filtered data
description = filtered_data.describe()
# Print the statistics for the specified years
print(description)
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   349.000000  349.000000  349.000000  349.000000  349.000000
# mean   1905.489971   19.247564   22.148138   24.093123   40.112894
# std       2.874389   27.969593   34.263440   41.199748   62.415463
# min    1901.000000    0.000000    0.000000    0.000000    0.000000
# 25%    1903.000000    1.700000    0.700000    0.600000    1.700000
# 50%    1905.000000    7.000000    7.500000    7.100000   13.100000
# 75%    1908.000000   24.200000   26.600000   29.400000   48.900000
# max    1910.000000  146.700000  195.800000  306.500000  457.100000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  349.000000   349.000000   349.000000   349.000000  349.000000
# mean    70.991691   211.944699   329.113754   284.161605  183.251289
# std     98.883373   225.455573   268.659146   175.598556  125.303008
# min      0.000000     2.700000     0.000000     0.000000    0.200000
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Defining the data
#Read your dataset from a CSV file and store it in a DataFrame
data = pd.read_csv('/content/rainfall in india 1901-2015 (2) (1).csv')
# Function to plot histograms
def plot_histograms(data):
    for column in data.columns[1:]:  # Exclude the 'YEAR' column
        plt.figure(figsize=(6, 4))
        plt.hist(data[column], bins=20, alpha=0.5, color='skyblue')  # Adjust the color as needed
        plt.xlabel(column)
        plt.ylabel("Frequency")
        plt.title(f'Histogram of {column}')
        plt.grid(True)
        plt.show()
# Function to plot line graph
def plot_line_graph(data):
    plt.figure(figsize=(10, 6))
    plt.plot(data['YEAR'], data['ANNUAL'], marker='o', color='green', linestyle='-', markersize=8, label='ANNUAL')
    plt.xlabel('YEAR')
    plt.ylabel('ANNUAL')
    plt.title('Annual Rainfall Over Time')
    plt.grid(True)
    plt.legend()
    plt.show()
# Plot histograms
plot_histograms(data)
# Plot line graph
plot_line_graph(data)

# %%
# Import the necessary library for data visualization
import matplotlib.pyplot as plt

# Sample data for years and monthly rainfall
years = [1905, 1906, 1908]
monthly_rainfall = [
    [1.30, 0.00, 3.30, 26.90, 279.50, 628.70, 368.70, 330.50, 297.00, 260.70, 25.40, 344.70],  # Rainfall data for 1905
    [36.60, 0.00, 0.00, 0.00, 556.10, 733.30, 247.70, 320.50, 164.30, 267.80, 128.90, 79.20],  # Rainfall data for 1906
    [20.90, 85.10, 0.00, 29.00, 562.00, 693.60, 481.40, 699.90, 428.80, 170.70, 208.10, 196.90]  # Rainfall data for 1908
]

# Plot the data for each year
for year, rainfall in zip(years, monthly_rainfall):
    plt.plot(range(1, 13), rainfall, label=str(year))

# Add labels and a legend
plt.xlabel('Months')
plt.ylabel('Rainfall (mm)')
plt.title('Monthly Rainfall Over the Years')
plt.legend()

# Display a grid for reference
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=102)
x['bias'] = 1

x = x.values
y = y.values

def linear_regression(x, y):
    x_transpose = np.transpose(x)
    x_transpose_dot_x = np.dot(x_transpose, x)
    x_transpose_dot_y = np.dot(x_transpose, y)
    coefficients = np.linalg.solve(x_transpose_dot_x, x_transpose_dot_y)
    return coefficients

coefficients = linear_regression(x, y)

y_pred = np.dot(x, coefficients)
msqe = np.mean((y - y_pred) ** 2)
print("Mean Squared Error:", msqe)
# Out:
# Mean Squared Error: 9852.84269442688

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=102)
model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)

mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mse)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Squared Error (MSE): 10410.13145088592
# Mean Absolute Error (MAE): 15.271384911767539
# Root Mean Squared Error (RMSE): 102.03005170480861

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=102)

model = LinearRegression()
model.fit(x_train, y_train)

n_bootstrap_iterations = 100

mse_values = []
mae_values = []
rmse_values = []

# Perform bootstrapping
for _ in range(n_bootstrap_iterations):
    # Resample the training data with replacement
    indices = np.random.choice(len(x_train), len(x_train), replace=True)
    x_bootstrap = x_train[indices]
    y_bootstrap = y_train[indices]

    # Fit the model to the bootstrapped data
    model.fit(x_bootstrap, y_bootstrap)

    # Make predictions on the test set
    y_pred = model.predict(x_test)

    # Calculate performance metrics for this iteration
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mse)

    # Append the metrics to the respective lists
    mse_values.append(mse)
    mae_values.append(mae)
    rmse_values.append(rmse)

# Calculate and print the average and standard deviation of the metrics
avg_mse = np.mean(mse_values)
std_mse = np.std(mse_values)
avg_mae = np.mean(mae_values)
std_mae = np.std(mae_values)
avg_rmse = np.mean(rmse_values)
std_rmse = np.std(rmse_values)

print("Mean Squared Error (MSE) - Avg:", avg_mse, "Std:", std_mse)
print("Mean Absolute Error (MAE) - Avg:", avg_mae, "Std:", std_mae)
print("Root Mean Squared Error (RMSE) - Avg:", avg_rmse, "Std:", std_rmse)
# Out:
# Mean Squared Error (MSE) - Avg: 9799.833007285419 Std: 1285.525201729244
# Mean Absolute Error (MAE) - Avg: 14.569073705512634 Std: 5.939070841288
# Root Mean Squared Error (RMSE) - Avg: 98.77554175168486 Std: 6.574599527467694

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Load your dataset
data = pd.read_csv('/content/rainfall in india 1901-2015 (2) (1).csv')

# Extract the relevant columns for features (x_data) and the target variable (y_data)
x_data = data.iloc[:, 2:].values  # Exclude the first two columns (Subdivision and Year)

# Replace 'Target_Variable_Column_Name' with the actual name of your target variable column
target_variable_name = 'Replace_with_Actual_Column_Name'

if target_variable_name in data.columns:
    y_data = data[target_variable_name].values

        # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(x_data, y_data)

                    # Make predictions
    y_pred = model.predict(x_data)

                            # Calculate Mean Squared Error
    mse = mean_squared_error(y_data, y_pred)
    print("Mean Squared Error:", mse)
    else:
    raise ValueError(f"Target variable column '{target_variable_name}' not found in the dataset.")
# Out:
#   File "<ipython-input-30-05da2a2af255>", line 28
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# Assuming you have loaded your dataset into the 'data' DataFrame

# Extract the target variable 'ANNUAL' and features
y = data['ANNUAL'].fillna(0)
X = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].fillna(0)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# Create an SVR (Support Vector Regression) model
svr = SVR(kernel='linear')
# Fit the SVR model to the training data
svr.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = svr.predict(X_test)

# Plot the predicted vs. actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='b', label='Actual vs. Predicted')
plt.xlabel('Actual Annual Rainfall')
plt.ylabel('Predicted Annual Rainfall')
plt.title('SVM Regression: Actual vs. Predicted Annual Rainfall')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b3d086afdc17> in <cell line: 10>()
#       8
#       9 # Extract the target variable 'ANNUAL' and features
# ---> 10 y = data['ANNUAL'].fillna(0)
#      11 X = data[['Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']].fillna(0)
#      12
#
# TypeError: list indices must be integers or slices, not str

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer

# Load your dataset (data should contain the features and target variable)
data = pd.read_csv('/content/rainfall in india 1901-2015 (2).csv')

# Define the features (X) and target variable (y)
X = data.drop(['ANNUAL', 'SUBDIVISION'], axis=1)

# Use SimpleImputer to handle missing values in the target variable (y)
imputer = SimpleImputer(strategy='mean')
y = imputer.fit_transform(data['ANNUAL'].values.reshape(-1, 1)).flatten()

# Split the data into a training set and a testing set (e.g., 80% for training, 20% for testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# Initialize and train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Calculate the mean squared error and R-squared (coefficient of determination)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the accuracy metrics
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ecded107afe0> in <cell line: 22>()
#      20 # Initialize and train a linear regression model
#      21 model = LinearRegression()
# ---> 22 model.fit(X_train, y_train)
#      23
#      24 # Make predictions on the testing set
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
# ...

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

svm_classifier = SVR( C=2)
svm_classifier.fit(x_train, y_train)
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.30, random_state=100+1)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = svm_classifier.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred,squared=False)
r2 = r2_score(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Read the dataset
data = pd.read_csv('/content/rainfall in india 1901-2015 (2) (1).csv')

# Prepare the target variable 'y' and features 'x'
y = data['ANNUAL'].fillna(0)
x = data.drop(['ANNUAL', 'SUBDIVISION'], axis=1).fillna(0)
x['bias'] = 1

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=100+1)

# Linear Regression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Linear Regression:")
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
# Support Vector Regression
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.30, random_state=100+1)
svm_classifier = SVR(C=2)
svm_classifier.fit(x_train, y_train)
y_pred_svm = svm_classifier.predict(x_test)

mae_svm = mean_absolute_error(y_test, y_pred_svm)
mse_svm = mean_squared_error(y_test, y_pred_svm)
rmse_svm = np.sqrt(mse_svm)
r2 = r2_score(y_test, y_pred_svm)

print("Support Vector Regression:")
print("Mean Absolute Error (MAE):", mae_svm)
print("Mean Squared Error (MSE):", mse_svm)
print("Root Mean Squared Error (RMSE):", rmse_svm)
print("R-squared (R2) Score:", r2)

# You can plot the graph for target variables and feature space here if needed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Create a pandas DataFrame from the provided data

# Remove rows with missing values
data = data.dropna()
# Extract the feature and target variables
X = data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']]
y = data['ANNUAL']
# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)
# Make predictions using the model
y_pred = model.predict(X)
# Create a figure for the plot with a specified size
plt.figure(figsize=(10, 6))
# Plot the actual annual rainfall against the predicted values
plt.scatter(data['YEAR'], data['ANNUAL'], label='Actual', color='b', marker='o')
plt.plot(data['YEAR'], y_pred, label='Predicted', color='r', linestyle='--')
plt.title('Actual vs. Predicted Annual Rainfall')
plt.xlabel('Year')
plt.ylabel('Annual Rainfall')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Create a KDE plot for the 'ANNUAL' rainfall data
# Set the figure size to (10, 6) for a larger plot
plt.figure(figsize=(10, 6))

# Use Seaborn's kdeplot to create a Kernel Density Estimation plot
# Shade the area under the curve for better visualization
# Set the color to 'b' for blue
sns.kdeplot(data['ANNUAL'], shade=True, color='b')

# Set the title of the plot
plt.title('Kernel Density Estimation for Annual Rainfall')

# Label the x-axis
plt.xlabel('Annual Rainfall')

# Label the y-axis
plt.ylabel('Density')

# Display a grid on the plot for reference
plt.grid(True)

# Show the KDE plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Create a DataFrame with the target variable and features
data_to_plot = data.copy()
# Specify the columns you want to include in the pair plot (features and the target)
columns_to_plot = ['ANNUAL', 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']  # Replace with actual feature names
# Create pair plots without KDE on the diagonal
sns.pairplot(data_to_plot[columns_to_plot])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2322752cde0> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 # Create a DataFrame with the target variable and features
# ----> 4 data_to_plot = data.copy()
#       5 # Specify the columns you want to include in the pair plot (features and the target)
#       6 columns_to_plot = ['ANNUAL', 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec']  # Replace with actual feature names
#
# NameError: name 'data' is not defined
